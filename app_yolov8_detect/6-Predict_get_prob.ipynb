# %% [markdown]
# ### Leia essa ducmentação para ver os argumentos e como funciona o predict
#
# https://docs.ultralytics.com/modes/predict/#inference-sources

# %% [markdown]
# #### Pegar dados de probabilidade
#
# Forma de pegar alguns dados

# %%
import cv2
from ultralytics import YOLO

video_path = "video/PESSIMA 23-06-26.mp4"
model = YOLO('./runs/detect/train14/weights/best.pt',)

cap = cv2.VideoCapture(0)


while True:
    if cap.isOpened():
        # Read a frame from the video
        success, frame = cap.read()
        if success:
            # Redimensione o quadro
            #frame = cv2.resize(frame, (largura_desejada, altura_desejada))

            # Execute a inferência YOLOv8 no quadro
            results = model(frame, device=0, max_det = 1,  imgsz=640)

       
            # Visualize os resultados no quadro
            annotated_frame = results[0].plot(masks=True, kpt_line=True, labels=True, boxes=True)

            #print(results[0].boxes)
            #results[0].boxes.xyxy   # box with xyxy format, (N, 4)
            #results[0].boxes.xywh   # box with xywh format, (N, 4)
            #results[0].boxes.xyxyn  # box with xyxy format but normalized, (N, 4)
            #results[0].boxes.xywhn  # box with xywh format but normalized, (N, 4)
            print(results[0].boxes.conf)   # confidence score, (N, 1)
            #results[0].boxes.cls    # cls, (N, 1)


            #print(annotated_frame)

            #print(results[0].probs)

            #print(results[0].names)

            # Exiba o quadro anotado
            cv2.imshow("Inference", annotated_frame)

            # Pressione 'q' para interromper a execução
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
            # Encerre o loop quando o final do vídeo for alcançado
            break

# Libere o objeto de captura de vídeo e feche a janela de exibição
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 78.5ms
# Speed: 3.0ms preprocess, 78.5ms inference, 44.3ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 0.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 0.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 0.0ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 0.0ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 0.5ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 0.0ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 0.0ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 0.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.5ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 0.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 0.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 0.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 0.0ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 0.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 0.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.0ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.2ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 0.5ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 0.0ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 0.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')
#
# 0: 480x640 (no detections), 15.1ms
# Speed: 1.1ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\igor8\Desktop\Programacao\yolov8_detection_with_label_studio\app_yolov8_detect\6-Predict_get_prob.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> results = model(frame, device=0, max_det = 1,  imgsz=640)
#      <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a> # Visualize os resultados no quadro
# ---> <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a> annotated_frame = results[0].plot(masks=True, kpt_line=True, labels=True, boxes=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=24'>25</a> #print(results[0].boxes)
#      <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=25'>26</a> #results[0].boxes.xyxy   # box with xyxy format, (N, 4)
#      <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=26'>27</a> #results[0].boxes.xywh   # box with xywh format, (N, 4)
#      <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a> #results[0].boxes.xyxyn  # box with xyxy format but normalized, (N, 4)
#      <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a> #results[0].boxes.xywhn  # box with xywh format but normalized, (N, 4)
#      <a href='vscode-notebook-cell:/c%3A/Users/igor8/Desktop/Programacao/yolov8_detection_with_label_studio/app_yolov8_detect/6-Predict_get_prob.ipynb#W2sZmlsZQ%3D%3D?line=29'>30</a> print(results[0].boxes.conf)   # confidence score, (N, 1)
#
# File c:\Users\igor8\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ultralytics\engine\results.py:224, in Results.plot(self, conf, line_width, font_size, font, pil, img, im_gpu, kpt_radius, kpt_line, labels, boxes, masks, probs)
#     222 pred_masks, show_masks = self.masks, masks
#     223 pred_probs, show_probs = self.probs, probs
# --> 224 annotator = Annotator(
#     225     deepcopy(self.orig_img if img is None else img),
#     226     line_width,
#     227     font_size,
#     228     font,
#     229     pil or (pred_probs is not None and show_probs),  # Classify tasks default to pil=True
#     230     example=names)
#     232 # Plot Segment results
#     233 if pred_masks and show_masks:
#
# File c:\Users\igor8\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ultralytics\utils\plotting.py:81, in Annotator.__init__(self, im, line_width, font_size, font, pil, example)
#      79 self.lw = line_width or max(round(sum(im.shape) / 2 * 0.003), 2)  # line width
#      80 if self.pil:  # use PIL
# ---> 81     self.im = im if isinstance(im, Image.Image) else Image.fromarray(im)
#      82     self.draw = ImageDraw.Draw(self.im)
#      83     try:
#
# File c:\Users\igor8\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\PIL\Image.py:3013, in fromarray(obj, mode)
#    3010     else:
#    3011         obj = obj.tostring()
# -> 3013 return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#
# File c:\Users\igor8\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\PIL\Image.py:2940, in frombuffer(mode, size, data, decoder_name, *args)
#    2937         im.readonly = 1
#    2938         return im
# -> 2940 return frombytes(mode, size, data, decoder_name, args)
#
# File c:\Users\igor8\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\PIL\Image.py:2882, in frombytes(mode, size, data, decoder_name, *args)
#    2879     args = mode
#    2881 im = new(mode, size)
# -> 2882 im.frombytes(data, decoder_name, args)
#    2883 return im
#
# File c:\Users\igor8\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\PIL\Image.py:812, in Image.frombytes(self, data, decoder_name, *args)
#     810 d = _getdecoder(self.mode, decoder_name, args)
#     811 d.setimage(self.im)
# --> 812 s = d.decode(data)
#     814 if s[0] >= 0:
#     815     raise ValueError("not enough image data")
#
# KeyboardInterrupt:

# %% [markdown]
# | Name          | Type          | Default   | Description                                           |
# |---------------|---------------|-----------|-------------------------------------------------------|
# | source        | str           | 'ultralytics/assets' | diretório de origem para imagens ou vídeos    |
# | conf          | float         | 0.25      | limite de confiança do objeto para detecção        |
# | iou           | float         | 0.7       | limite de interseção sobre união (IoU) para NMS   |
# | imgsz         | int ou tuple   | 640       | tamanho da imagem como escalar ou lista (h, w)  |
# | half          | bool          | False     | usar meia precisão (FP16)                           |
# | device        | None ou str    | None      | dispositivo para executar, ou seja, cuda device=0/1/2/3 ou device=cpu |
# | show          | bool          | False     | mostrar resultados, se possível                    |
# | save          | bool          | False     | salvar imagens com resultados                       |
# | save_txt      | bool          | False     | salvar resultados como arquivo .txt                |
# | save_conf     | bool          | False     | salvar resultados com pontuações de confiança     |
# | save_crop     | bool          | False     | salvar imagens recortadas com resultados           |
# | hide_labels   | bool          | False     | ocultar rótulos                                     |
# | hide_conf     | bool          | False     | ocultar pontuações de confiança                      |
# | max_det       | int           | 300       | número máximo de detecções por imagem              |
# | vid_stride    | bool          | False     | passo de taxa de quadros de vídeo                   |
# | stream_buffer | bool          | False     | buffer para todos os quadros de streaming (True) ou retornar o quadro mais recente (False) |
# | line_width    | None ou int   | None      | a largura da linha das caixas delimitadoras. Se None, é escalado para o tamanho da imagem. |
# | visualize     | bool          | False     | visualizar características do modelo                |
# | augment       | bool          | False     | aplicar aumento de imagem às fontes de previsão     |
# | agnostic_nms  | bool          | False     | NMS agnóstico de classe                             |
# | retina_masks  | bool          | False     | usar máscaras de segmentação de alta resolução     |
# | classes       | None ou lista | None      | filtrar resultados por classe, ou seja, classes=0, ou classes=[0,2,3] |
# | boxes         | bool          | True      | mostrar caixas nas previsões de segmentação         |
